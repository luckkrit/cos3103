# %%
# !pip install jupysql psycopg2-binary

# %%
# %load_ext sql
# Show more rows in results
# %config SqlMagic.displaylimit = 300
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:password@localhost:5432/postgres

# %%
# %sql SELECT version()

# %%
# %sql SET search_path TO classicmodels, public

# %%
# %%sql
# SELECT * FROM products
# WHERE productLine = 'Classic Cars'

# %%
# %%sql
# SELECT * FROM orders o inner join orderdetails d on o.ordernumber = d.ordernumber
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 2996 rows affected.
# +-------------+---------------------+---------------------+---------------------+---------+------------------------+----------------+---------------+-------------+-----------------+-----------+-----------------+
# | ordernumber |      orderdate      |     requireddate    |     shippeddate     |  status |        comments        | customernumber | ordernumber_1 | productcode | quantityordered | priceeach | orderlinenumber |
# +-------------+---------------------+---------------------+---------------------+---------+------------------------+----------------+---------------+-------------+-----------------+-----------+-----------------+
# |    10100    | 2003-01-06 00:00:00 | 2003-01-13 00:00:00 | 2003-01-10 00:00:00 | Shipped |          None          |      363       |     10100     |   S18_1749  |        30       |    136    |        3        |
# ...

# %%
# %%sql
# SELECT employeeNumber, customerNumber
# FROM classicmodels.customers as c
# RIGHT JOIN classicmodels.employees as e
# ON c.salesRepEmployeeNumber = e.employeeNumber
# order by customernumber DESC
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 108 rows affected.
# +----------------+----------------+
# | employeenumber | customernumber |
# +----------------+----------------+
# |      1076      |      None      |
# |      1088      |      None      |
# |      1619      |      None      |
# |      1002      |      None      |
# |      1625      |      None      |
# |      1102      |      None      |
# |      1056      |      None      |
# |      1143      |      None      |
# |      1612      |      496       |
# |      1188      |      495       |
# |      1501      |      489       |
# |      1165      |      487       |
# |      1323      |      486       |
# |      1702      |      484       |
# |      1166      |      475       |
# |      1401      |      473       |
# |      1611      |      471       |
# |      1216      |      462       |
# |      1702      |      458       |
# |      1286      |      456       |
# ...
