# %%
# !pip install jupysql psycopg2-binary
# Out:
# Collecting jupysql
#   Using cached jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: psycopg2-binary in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (2.9.11)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlalchemy in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (2.0.45)
# Requirement already satisfied: sqlparse in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (28.5.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: pyyaml in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (7.4.3)
# Requirement already satisfied: wcwidth in c:\users\luckk\appdata\roaming\python\python312\site-packages (from prettytable>=3.12.0->jupysql) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from jinja2->jupysql) (3.0.2)
# Requirement already satisfied: greenlet>=1 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy->jupysql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy->jupysql) (4.14.1)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\luckk\appdata\roaming\python\python312\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\luckk\appdata\roaming\python\python312\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luckk\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2025.8.3)
# Using cached jupysql-0.11.1-py3-none-any.whl (95 kB)
# Installing collected packages: jupysql
# Successfully installed jupysql-0.11.1
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:password@localhost:5432/postgres
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/postgres'

# %%
# %sql SELECT version()
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 1 rows affected.
# +-------------------------------------------------------------------------+
# |                                 version                                 |
# +-------------------------------------------------------------------------+
# | PostgreSQL 18.1 on x86_64-windows, compiled by msvc-19.44.35219, 64-bit |
# +-------------------------------------------------------------------------+

# %%
# %sql SET search_path TO classicmodels, public
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM products
# WHERE productLine = 'Classic Cars'
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 38 rows affected.
# +-------------+--------------------------+--------------+---------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------+--------+--------------+
# | productcode |       productname        | productscale |       productvendor       |                                                                                                           productdescription                                                                                                          | quantityinstock | buyprice |  msrp  | productline  |
# +-------------+--------------------------+--------------+---------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------+--------+--------------+
# |   S10_1949  | 1952 Alpine Renault 1300 |     1:10     |  Classic Metal Creations  |                                            Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.                                            |       7305      |  98.58   | 214.3  | Classic Cars |
# |   S10_4757  |   1972 Alfa Romeo GTA    |     1:10     |  Motor City Art Classics  |                                   Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.                                   |       3252      |  85.68   |  136   | Classic Cars |
# |   S10_4962  |  1962 LanciaA Delta 16V  |     1:10     |    Second Gear Diecast    |                                   Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.                                   |       6791      |  103.42  | 147.74 | Classic Cars |
# |   S12_1099  |    1968 Ford Mustang     |     1:12     |   Autoart Studio Design   |                                             Hood, doors and trunk all open to reveal highly detailed interior features. Steering wheel actually turns the front wheels. Color dark green.                                             |        68       |  95.34   | 194.57 | Classic Cars |
# |   S12_1108  |    2001 Ferrari Enzo     |     1:12     |    Second Gear Diecast    |                                            Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.                                            |       3619      |  95.59   | 207.8  | Classic Cars |
# |   S12_3148  |    1969 Corvair Monza    |     1:18     | Welly Diecast Productions |                                                                      1:18 scale die-cast about 10 inches long doors open, hood opens, trunk opens and wheels roll                                                                     |       6906      |  89.14   | 151.08 | Classic Cars |
# |   S12_3380  |    1968 Dodge Charger    |     1:12     | Welly Diecast Productions |                           1:12 scale model of a 1968 Dodge Charger. Hood, doors and trunk all open to reveal highly detailed interior features. Steering wheel actually turns the front wheels. Color black                           |       9123      |  75.16   | 117.44 | Classic Cars |
# |   S12_3891  |     1969 Ford Falcon     |     1:12     |    Second Gear Diecast    |                                            Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.                                            |       1049      |  83.05   | 173.02 | Classic Cars |
# |   S12_3990  | 1970 Plymouth Hemi Cuda  |     1:12     |    Studio M Art Models    | Very detailed 1970 Plymouth Cuda model in 1:12 scale. The Cuda is generally accepted as one of the fastest original muscle cars from the 1970s. This model is a reproduction of one of the orginal 652 cars built in 1970. Red color. |       5663      |  31.92   |  79.8  | Classic Cars |
# |   S12_4675  |    1969 Dodge Charger    |     1:12     | Welly Diecast Productions |                                                Detailed model of the 1969 Dodge Charger. This model includes finely detailed interior and exterior features. Painted in red and white.                                                |       7323      |  58.73   | 115.16 | Classic Cars |
# +-------------+--------------------------+--------------+---------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+----------+--------+--------------+
# Truncated to displaylimit of 10.
